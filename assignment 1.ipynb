# %% [markdown]
# # Task 1:

# %% [markdown]
# 1. Install Jupyter notebook and run the first program and share the screenshot of the output.

# %%
from IPython.display import Image
Image("Image.png")

# %% [markdown]
# 2. Write a program which will find all such numbers which are divisible by 7 but are not multiple of 5, between 2000 and 3200(both included). The numbers obtained should be printed in a comma-separated on a single line.

# %%
output= []
for i in range(2000, 3201):
    if(i%7==0) and (i%5!=0):
        output.append(i)
print(*output, sep=",", end=".")
# Out:
# 2002,2009,2016,2023,2037,2044,2051,2058,2072,2079,2086,2093,2107,2114,2121,2128,2142,2149,2156,2163,2177,2184,2191,2198,2212,2219,2226,2233,2247,2254,2261,2268,2282,2289,2296,2303,2317,2324,2331,2338,2352,2359,2366,2373,2387,2394,2401,2408,2422,2429,2436,2443,2457,2464,2471,2478,2492,2499,2506,2513,2527,2534,2541,2548,2562,2569,2576,2583,2597,2604,2611,2618,2632,2639,2646,2653,2667,2674,2681,2688,2702,2709,2716,2723,2737,2744,2751,2758,2772,2779,2786,2793,2807,2814,2821,2828,2842,2849,2856,2863,2877,2884,2891,2898,2912,2919,2926,2933,2947,2954,2961,2968,2982,2989,2996,3003,3017,3024,3031,3038,3052,3059,3066,3073,3087,3094,3101,3108,3122,3129,3136,3143,3157,3164,3171,3178,3192,3199.

# %% [markdown]
# 3. Write a Python program to accept the user's first and last name and then getting them printed in the reverse order with a space between first name and last name.

# %%
first_name= input("Input your First Name:")
last_name= input("Input your Last Name:")
print("Your name is reverse order is: "+last_name+" "+first_name)
# Out:
# Input your First Name:k
# Input your Last Name:l
# Your name is reverse order is: l k

# %% [markdown]
# 4. Write a Python program to find the colume of a sphere with diameter 12 cm.

# %%
import math
diameter= input("Enter diameter:")
volume= (4/3)*3.142*math.pow(float(diameter)/2,3)
print("volume of sphere is: "+str(volume)+" if diameter is:" +str(diameter))
# Out:
# Enter diameter:12
# volume of sphere is: 904.896 if diameter is:12

# %% [markdown]
# # Task 2:

# %% [markdown]
# 1. Write a program which accepts a sequence of comma-separated numbers from console and generate a list.

# %%
values= input("Input comma-separated numbers:")
list= values.split(",")
print("list:",list)
# Out:
# Input comma-separated numbers:567,789
# list: ['567', '789']

# %% [markdown]
# 2. Create the below pattern using nested for loop in Python.

# %%
n=5
for i in range(n):
    for j in range(i):
        print("*", end="")
    print("")
for i in range(n,0,-1):
    for j in range(i):
        print("*", end="")
    print("")
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %% [markdown]
# 3. Write a Python program to reverse a word after accepting the input from the user.

# %%
word= input(str("Enter word:"))
print(word[::-1])
# Out:
# Enter word:AcadGild
# dliGdacA

# %% [markdown]
# 4.

# %%
print("WE, THE PEOPLE OF INDIA,\n\t having solemnly resolved to constitute India into a SOVEREIGN,!\n\t\tSOCIALIST, SECULAR, DEMOCRATIC REPUBLIC \n\t\t and to secure to all its citizens")
# Out:
# WE, THE PEOPLE OF INDIA,
# 	 having solemnly resolved to constitute India into a SOVEREIGN,!
# 		SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC
# 		 and to secure to all its citizens
